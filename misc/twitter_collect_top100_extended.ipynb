# %% [markdown]
# ## **NOTE:** this notebook copied from `twitter_collect_top100.ipynb` but modified to include 'extended' tweet information. This ensures tweet text is NOT truncated [for tweets longer than 140chars in length] AND it provides URLs for any images contained within the tweet!
#
# ## NOTE: No need to run this notebook. I supplied it so you can see HOW the twitter data is collected :)
# ## For actually USING the data collected here look at the <b>'twitter_unpackTop100_example.ipynb'</b> notebook!

# %% [markdown]
# ## Load Modules
# - ttools has helper functions

# %%
# %load_ext autoreload
# %autoreload 2
import sys, codecs, json
import ttools
from twython import TwythonStreamer, Twython
from datetime import datetime
from time import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get top100 [from pre-made json file]
# First, load the dictionary with the top100 most followed twtter users and extract the user_ids for use in api

# %%
top100file = './top100_id_dictionary.json'
top100 = ttools.json_to_dict(top100file)  # format is {user_id:[username,name]} really we just care about the user ids for now
top100ids = [int(uid) for uid in top100.keys()]

# %% [markdown]
# ## Set up twitter API, get user metadata, and remove non-english accounts
# Initialize the api connection

# %%
app_key = "YOUR_API_KEY_HERE"  #api_key
app_sec = "YOUR_API_SECRET_KEY_HERE"  #api_secretKey
user_key = "YOUR_ACCESS_TOKEN_HERE"  #access_token
user_sec = "YOUR_ACCESS_TOKEN_SECRET_HERE"  #access_token_secret
api = ttools.initAPI(app_key,app_sec,user_key,user_sec)
credentials = api.verify_credentials()  #KRC__verify the connection

# %% [markdown]
# Get all users metadata from direct users_lookup api [can gather 100 users in a single api call..how convenient!]

# %%
userdata = api.lookup_user(user_id=[top100ids])
#for some reason the api is not getting the 1st and last users....
num1 = api.lookup_user(user_id=[top100ids[0]])
num100 = api.lookup_user(user_id=[top100ids[-1]])
userdata.append(num1[0])
userdata.append(num100[0])

# %% [markdown]
# Check and clean the data we collected

# %%
#verify we got all the users
usersGotten = []
for d in userdata:
    usersGotten.append(int(d['id']))
commonUsers = set(top100ids).intersection(set(usersGotten))
if len(commonUsers) != 100:
    print('api did not give all/correct user ids...need to investigate')

#remove the non-english accounts [actually, do this in-loop below]
# nonEnglish = []
# for d in userdata:
#     if d['lang'] != 'en':
#         nonEnglish.append(d['id'])
#         print('removing non-english account: %s'%(top100[str(d['id'])]))
#         top100.pop(str(d['id']))
# print('top100 is composed of %s english speakers'%(len(top100)))

# %% [markdown]
# ## Collect Timeline Data and Save json
# Now, let's gather the timeline data! Note the user information we just collected is used in the 'user_info' key of the limitedUserDict [which is the one collecting ALL of the data]. The data will be saved in a *json format

# %%
# %%time
numPasses = 1
currentUserID = 0
timeStart = time()
allCollectedUsers = []  #track users we successfully got timelines for

limitedUserDict = {}
try:
    for i,udata in enumerate(userdata):
        user_id = int(udata['id'])
        #skip the non-english accounts
        if udata['lang'] != 'en':
            print('skipping non-english user: %s'%(udata['screen_name']))
            #top100.pop(str(d['id']))  #remove from the top100 list...not really necessary
            continue
        currentUserID = user_id
        limitedUserDict[int(user_id)] = {'user_info':udata,'user_timeline':[]}  #hydrates the user info and preps the timeline list
        #limitedUserDict[int(user_id)] = activeusers[int(user_id)]  #copy the structure for the user
        print('%s__of__%s total users gathered'%(i,len(top100ids)))
        print('User ID: %s'%user_id)
        print('username: %s'%udata['screen_name'])
        kwargs = {'user_id':int(user_id),'count':200,'exclude_replies':'false','trim_user':'true','include_rts':'false','tweet_mode':'extended'}
        timelineTweets = ttools.rateLimitWrapperTimeline(api,api.get_user_timeline,kwargs,willingToWait=True,maxExecTime=14400)
        limitedUserDict[user_id]['user_timeline'].extend(timelineTweets)  #extend the list
        allCollectedUsers.append(user_id)
        del timelineTweets
except:
    print('some sort of error occurred...dumping data collected so far')
    jsonStr = json.dumps(limitedUserDict)
    with open('top100users_and_timelines_EXTENDED.json','w') as f:
        f.write(jsonStr)
    del jsonStr
    with open('top100gotten_EXTENDED.txt','w') as outF:
        outF.write('%s'%allCollectedUsers)
    print('last user_id attempted = %s'%currentUserID)
    print('total number of users collected: %s'%(len(allCollectedUsers)))
    print('finished!')
    print('Elapsed time: %s'%(time() - timeStart))
    sys.exit()
#print(len(r))

print('made it to the end without error')
jsonStr = json.dumps(limitedUserDict)
with open('top100users_and_timelines_EXTENDED.json','w') as f:
    f.write(jsonStr)
del jsonStr
with open('top100gotten_EXTENDED.txt','w') as outF:
    outF.write('%s'%allCollectedUsers)
print('last user_id attempted = %s'%currentUserID)
print('total number of users collected: %s'%(len(allCollectedUsers)))
print('finished!')
print('Elapsed time: %s'%(time() - timeStart))
# Out:
# 0__of__100 total users gathered
# User ID: 27260086
# username: justinbieber
# returning from rateLimitWrapper
# 1__of__100 total users gathered
# User ID: 813286
# username: BarackObama
# returning from rateLimitWrapper
# 2__of__100 total users gathered
# User ID: 79293791
# username: rihanna
# returning from rateLimitWrapper
# 3__of__100 total users gathered
# User ID: 17919972
# username: taylorswift13
# returning from rateLimitWrapper
# 4__of__100 total users gathered
# User ID: 14230524
# username: ladygaga
# returning from rateLimitWrapper
# 5__of__100 total users gathered
# User ID: 15846407
# username: TheEllenShow
# returning from rateLimitWrapper
# skipping non-english user: Cristiano
# 7__of__100 total users gathered
# User ID: 10228272
# username: YouTube
# returning from rateLimitWrapper
# 8__of__100 total users gathered
# User ID: 26565946
# username: jtimberlake
# returning from rateLimitWrapper
# 9__of__100 total users gathered
# User ID: 25365536
# username: KimKardashian
# returning from rateLimitWrapper
# 10__of__100 total users gathered
# User ID: 34507480
# username: ArianaGrande
# returning from rateLimitWrapper
# 11__of__100 total users gathered
# User ID: 783214
# username: Twitter
# returning from rateLimitWrapper
# 12__of__100 total users gathered
# User ID: 21111883
# username: ddlovato
# returning from rateLimitWrapper
# 13__of__100 total users gathered
# User ID: 23375688
# username: selenagomez
# returning from rateLimitWrapper
# 14__of__100 total users gathered
# User ID: 16409683
# username: britneyspears
# returning from rateLimitWrapper
# 15__of__100 total users gathered
# User ID: 25073877
# username: realDonaldTrump
# returning from rateLimitWrapper
# 16__of__100 total users gathered
# User ID: 428333
# username: cnnbrk
# returning from rateLimitWrapper
# 17__of__100 total users gathered
# User ID: 44409004
# username: shakira
# returning from rateLimitWrapper
# 18__of__100 total users gathered
# User ID: 15485441
# username: jimmyfallon
# returning from rateLimitWrapper
# 19__of__100 total users gathered
# User ID: 50393960
# username: BillGates
# returning from rateLimitWrapper
# 20__of__100 total users gathered
# User ID: 18839785
# username: narendramodi
# returning from rateLimitWrapper
# 21__of__100 total users gathered
# User ID: 85603854
# username: JLo
# returning from rateLimitWrapper
# 22__of__100 total users gathered
# User ID: 100220864
# username: BrunoMars
# returning from rateLimitWrapper
# 23__of__100 total users gathered
# User ID: 807095
# username: nytimes
# returning from rateLimitWrapper
# 24__of__100 total users gathered
# User ID: 19397785
# username: Oprah
# returning from rateLimitWrapper
# 25__of__100 total users gathered
# User ID: 23083404
# username: KingJames
# returning from rateLimitWrapper
# skipping non-english user: neymarjr
# 27__of__100 total users gathered
# User ID: 759251
# username: CNN
# returning from rateLimitWrapper
# 28__of__100 total users gathered
# User ID: 268414482
# username: MileyCyrus
# returning from rateLimitWrapper
# 29__of__100 total users gathered
# User ID: 105119490
# username: NiallOfficial
# returning from rateLimitWrapper
# 30__of__100 total users gathered
# User ID: 5402612
# username: BBCBreaking
# returning from rateLimitWrapper
# 31__of__100 total users gathered
# User ID: 27195114
# username: Drake
# returning from rateLimitWrapper
# skipping non-english user: instagram
# 33__of__100 total users gathered
# User ID: 101311381
# username: iamsrk
# returning from rateLimitWrapper
# 34__of__100 total users gathered
# User ID: 145125358
# username: SrBachchan
# returning from rateLimitWrapper
# 35__of__100 total users gathered
# User ID: 26257166
# username: SportsCenter
# returning from rateLimitWrapper
# 36__of__100 total users gathered
# User ID: 132385468
# username: BeingSalmanKhan
# returning from rateLimitWrapper
# 37__of__100 total users gathered
# User ID: 23151437
# username: KevinHart4real
# returning from rateLimitWrapper
# 38__of__100 total users gathered
# User ID: 116362700
# username: LilTunechi
# returning from rateLimitWrapper
# 39__of__100 total users gathered
# User ID: 2557521
# username: espn
# returning from rateLimitWrapper
# 40__of__100 total users gathered
# User ID: 20322929
# username: wizkhalifa
# returning from rateLimitWrapper
# 41__of__100 total users gathered
# User ID: 84279963
# username: Louis_Tomlinson
# returning from rateLimitWrapper
# 42__of__100 total users gathered
# User ID: 181561712
# username: Harry_Styles
# returning from rateLimitWrapper
# 43__of__100 total users gathered
# User ID: 158314798
# username: LiamPayne
# returning from rateLimitWrapper
# 44__of__100 total users gathered
# User ID: 28706024
# username: Pink
# returning from rateLimitWrapper
# 45__of__100 total users gathered
# User ID: 209708391
# username: onedirection
# returning from rateLimitWrapper
# skipping non-english user: realmadrid
# 47__of__100 total users gathered
# User ID: 35094637
# username: aliciakeys
# returning from rateLimitWrapper
# 48__of__100 total users gathered
# User ID: 60865434
# username: KAKA
# returning from rateLimitWrapper
# 49__of__100 total users gathered
# User ID: 11348282
# username: NASA
# returning from rateLimitWrapper
# 50__of__100 total users gathered
# User ID: 119509520
# username: chrisbrown
# returning from rateLimitWrapper
# 51__of__100 total users gathered
# User ID: 96951800
# username: FCBarcelona
# returning from rateLimitWrapper
# 52__of__100 total users gathered
# User ID: 166739404
# username: EmmaWatson
# returning from rateLimitWrapper
# 53__of__100 total users gathered
# User ID: 115485051
# username: ConanOBrien
# returning from rateLimitWrapper
# 54__of__100 total users gathered
# User ID: 169686021
# username: kanyewest
# returning from rateLimitWrapper
# 55__of__100 total users gathered
# User ID: 31348594
# username: akshaykumar
# returning from rateLimitWrapper
# 56__of__100 total users gathered
# User ID: 184910040
# username: Adele
# returning from rateLimitWrapper
# 57__of__100 total users gathered
# User ID: 176566242
# username: zaynmalik
# ErrorCaught in loop
# returning from rateLimitWrapper
# 58__of__100 total users gathered
# User ID: 19923144
# username: NBA
# rate limit, sleeping before while loop
# ErrorCaught 1st
# 59__of__100 total users gathered
# User ID: 135421739
# username: sachin_rt
# ErrorCaught 1st
# 60__of__100 total users gathered
# User ID: 471741741
# username: PMOIndia
# ErrorCaught 1st
# 61__of__100 total users gathered
# User ID: 90420314
# username: ActuallyNPH
# ErrorCaught 1st
# 62__of__100 total users gathered
# User ID: 71201743
# username: imVkohli
# ErrorCaught 1st
# 63__of__100 total users gathered
# User ID: 157140968
# username: KendallJenner
# ErrorCaught 1st
# 64__of__100 total users gathered
# User ID: 31927467
# username: pitbull
# ErrorCaught 1st
# 65__of__100 total users gathered
# User ID: 25521487
# username: danieltosh
# ErrorCaught 1st
# 66__of__100 total users gathered
# User ID: 32959253
# username: khloekardashian
# returning from rateLimitWrapper
# 67__of__100 total users gathered
# User ID: 236699098
# username: KylieJenner
# returning from rateLimitWrapper
# 68__of__100 total users gathered
# User ID: 101695592
# username: deepikapadukone
# returning from rateLimitWrapper
# 69__of__100 total users gathered
# User ID: 113419517
# username: iHrithik
# returning from rateLimitWrapper
# 70__of__100 total users gathered
# User ID: 822215679726100480
# username: POTUS
# 71__of__100 total users gathered
# User ID: 19426551
# username: NFL
# returning from rateLimitWrapper
# 72__of__100 total users gathered
# User ID: 18863815
# username: coldplay
# returning from rateLimitWrapper
# 73__of__100 total users gathered
# User ID: 742143
# username: BBCWorld
# returning from rateLimitWrapper
# 74__of__100 total users gathered
# User ID: 88856792
# username: aamir_khan
# returning from rateLimitWrapper
# 75__of__100 total users gathered
# User ID: 23617610
# username: kourtneykardash
# returning from rateLimitWrapper
# 76__of__100 total users gathered
# User ID: 90836187
# username: andresiniesta8
# returning from rateLimitWrapper
# skipping non-english user: MesutOzil1088
# 78__of__100 total users gathered
# User ID: 1339835893
# username: HillaryClinton
# returning from rateLimitWrapper
# 79__of__100 total users gathered
# User ID: 18681139
# username: priyankachopra
# returning from rateLimitWrapper
# 80__of__100 total users gathered
# User ID: 5988062
# username: TheEconomist
# returning from rateLimitWrapper
# 81__of__100 total users gathered
# User ID: 44196397
# username: elonmusk
# returning from rateLimitWrapper
# 82__of__100 total users gathered
# User ID: 22940219
# username: Eminem
# returning from rateLimitWrapper
# 83__of__100 total users gathered
# User ID: 17471979
# username: NatGeo
# returning from rateLimitWrapper
# 84__of__100 total users gathered
# User ID: 627673190
# username: ChampionsLeague
# returning from rateLimitWrapper
# 85__of__100 total users gathered
# User ID: 73992972
# username: AvrilLavigne
# returning from rateLimitWrapper
# skipping non-english user: davidguetta
# skipping non-english user: MohamadAlarefe
# 88__of__100 total users gathered
# User ID: 35787166
# username: NICKIMINAJ
# returning from rateLimitWrapper
# 89__of__100 total users gathered
# User ID: 14920785
# username: blakeshelton
# returning from rateLimitWrapper
# 90__of__100 total users gathered
# User ID: 19895282
# username: arrahman
# returning from rateLimitWrapper
# 91__of__100 total users gathered
# User ID: 19248106
# username: MariahCarey
# returning from rateLimitWrapper
# 92__of__100 total users gathered
# User ID: 20536157
# username: Google
# returning from rateLimitWrapper
# 93__of__100 total users gathered
# User ID: 40255499
# username: ricky_martin
# returning from rateLimitWrapper
# 94__of__100 total users gathered
# User ID: 379408088
# username: ShawnMendes
# returning from rateLimitWrapper
# 95__of__100 total users gathered
# User ID: 1652541
# username: Reuters
# returning from rateLimitWrapper
# 96__of__100 total users gathered
# User ID: 85452649
# username: edsheeran
# returning from rateLimitWrapper
# skipping non-english user: AlejandroSanz
# 98__of__100 total users gathered
# User ID: 21447363
# username: katyperry
# returning from rateLimitWrapper
# 99__of__100 total users gathered
# User ID: 242245578
# username: Dr_alqarnee
# returning from rateLimitWrapper
# made it to the end without error
# last user_id attempted = 242245578
# total number of users collected: 92
# finished!
# Elapsed time: 1023.1854839324951
# CPU times: user 24.4 s, sys: 2.86 s, total: 27.3 s
# Wall time: 17min 3s

# %% [markdown]
# Now we take the raw tweetdata and extract our defined features and put them into a dataframe. then save that dataframe as a *.csv file!

# %%
with open('top100users_and_timelines_EXTENDED.json','r') as f:
    readstr = f.read()
    alldata = json.loads(readstr)
    del readstr

uNum = 0
infos = []
globalTweets = {}
for uid,data in alldata.items():
    print('user number: %s'%uNum)
    if 'ErrorCaught' in data:
        print('Handled User ErrorCaught')
        continue
    res,globalTweets = ttools.extractAllAttributes(uid,data,globalTweets,extended=True)
    if res is None:
        #print('extractAllAttributes returned None. Skipping')
        continue
    infos.append(res)
    uNum += 1
alldata = pd.concat(infos,axis=0,ignore_index=True)
alldata.to_csv('./top100users_and_timelines_EXTENDED_PLUS.csv',index=False)  #the PLUS is because we added a few attributes afterward lol
alldata.to_pickle('./top100users_and_timelines_EXTENDED_PLUS.pkl')
del infos
del alldata
# Out:
# user number: 0
# user number: 1
# user number: 2
# user number: 3
# user number: 4
# user number: 5
# user number: 6
# user number: 7
# user number: 8
# user number: 9
# user number: 10
# user number: 11
# user number: 12
# user number: 13
# user number: 14
# user number: 15
# user number: 16
# user number: 17
# user number: 18
# user number: 19
# user number: 20
# user number: 21
# user number: 22
# user number: 23
# user number: 24
# user number: 25
# user number: 26
# user number: 27
# user number: 28
# user number: 29
# user number: 30
# user number: 31
# user number: 32
# user number: 33
# user number: 34
# user number: 35
# user number: 36
# user number: 37
# user number: 38
# user number: 39
# user number: 40
# user number: 41
# user number: 42
# user number: 43
# user number: 44
# user number: 45
# user number: 46
# user number: 47
# user number: 48
# user number: 49
# user number: 50
# user number: 51
# user number: 52
# user number: 53
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# Handled Tweet ErrorCaught
# user number: 54
# user number: 55
# user number: 56
# user number: 57
# user number: 58
# user number: 58
# user number: 59
# user number: 60
# user number: 61
# user number: 62
# user number: 63
# user number: 64
# user number: 65
# user number: 66
# user number: 67
# user number: 68
# user number: 69
# user number: 70
# user number: 71
# user number: 72
# user number: 73
# user number: 74
# user number: 75
# user number: 76
# user number: 77
# user number: 78
# user number: 79
# user number: 80
# user number: 81
# user number: 82

# %% [markdown]
# And there you have it! Top100 most followed users on twitter and their timelines now in file: <b>top100users_and_timelines_EXTENDED.csv</b>

# %% [markdown]
# ## Look in 'top100users_and_timelines.csv' for example using the actual data!

# %% [markdown]
# ## After the fact...add the top100 users 'category' label [artist,company,athlete,politician,businessLeader] and resave the file

# %% [markdown]
# ## Get top100 [from pre-made json file]
# First, load the dictionary with the top100 most followed twtter users and extract the user_ids for use in api

# %%
top100file = './top100_id_dictionary.json'
top100 = ttools.json_to_dict(top100file)  # format is {user_id:[username,name]} really we just care about the user ids for now
top100ids = [int(uid) for uid in top100.keys()]

# %% [markdown]
# Read in and inspect the top100 tweet/timeline data!

# %%
# %time top100all = pd.read_csv('top100users_and_timelines_EXTENDED_PLUS.csv',lineterminator='\n')
# Out:
# CPU times: user 1.78 s, sys: 135 ms, total: 1.92 s
# Wall time: 1.93 s
# <string>:2: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
top100all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203993 entries, 0 to 203992
# Data columns (total 33 columns):
# tweet_id                 203993 non-null int64
# tweet_truncated          203993 non-null bool
# date                     203993 non-null object
# tweet_source             203970 non-null object
# tweet_lang               203993 non-null object
# tweet_coord              37 non-null object
# tweet_place              364 non-null object
# text                     203993 non-null object
# text_noMentions          203951 non-null object
# is_quote_status          203993 non-null bool
# is_reply_to_status       203993 non-null bool
# is_reply_to_user         203993 non-null bool
# numMentions              203993 non-null int64
# image_urls               65150 non-null object
# retweet_count            203993 non-null int64
# favorite_count           203993 non-null int64
# user_id                  203993 non-null int64
# user_name                203993 non-null object
# user_screen              203993 non-null object
# user_verified            203993 non-null bool
# user_lang                203993 non-null object
# user_description_text    162806 non-null object
# user_followers_count     203993 non-null int64
# user_friends_count       203993 non-null int64
# user_listed_count        203993 non-null int64
# user_favourites_count    203993 non-null int64
# user_statuses_count      203993 non-null int64
# user_location            131853 non-null object
# user_created_year        203993 non-null int64
# user_created_month       203993 non-null int64
# user_geo_enabled         203993 non-null bool
# user_img_url             203993 non-null object
# user_banner_url          197584 non-null object
# dtypes: bool(6), int64(12), object(15)
# memory usage: 43.2+ MB

# %% [markdown]
# Now, we need to categorize the top100. Here is some helper code. The 'top100cat' dataframe is the result.

# %%
##THIS WAS DONE IN twitter_unpackTop100_example.ipynb [below]
# #turn dict into dataframe
# top100forCategories = []
# for uid in list(top100.keys()):
#     top100forCategories.append([int(uid),top100[uid][0],top100[uid][1]])

# #save the dataframe
# pd.DataFrame(top100forCategories).to_csv('top100categorization.csv')
# #then, manually labeled each entry as one of the five categories. Saved labeled file as 'top100categorization_complete.csv'
##THIS WAS DONE IN twitter_unpackTop100_example.ipynb [above]

#Now, read in the complete csv. This df can be used with the 'top100users_and_timelines.csv' dataset to help
#categorize the top100 users/tweets into correct category
CATEGORY = {'a':'artist','b':'businessLeader','c':'company','p':'politician','t':'athlete'}
top100cat = pd.read_csv('top100categorization_complete.csv')
top100cat.drop(['Unnamed: 0','notes'],axis=1,inplace=True)
top100cat.rename(columns={'0':'user_id','1':'screenname','2':'name'},inplace=True)
print('top100 category count:\n%s'%(top100cat['category'].value_counts().rename(CATEGORY)))
#top100cat.info()
# Out:
# top100 category count:
# artist            60
# company           14
# athlete            9
# politician         7
# businessLeader     2
# Name: category, dtype: int64

# %%
#decode the category labels [turn char into str]
top100cat['category'] = top100cat['category'].apply(lambda x: CATEGORY[x])  # using dict

#add the category 
res = top100all.merge(top100cat[['user_id','category']],on=['user_id'])
res.columns
# Out:
# Index(['tweet_id', 'tweet_truncated', 'date', 'tweet_source', 'tweet_lang',
#        'tweet_coord', 'tweet_place', 'text', 'text_noMentions',
#        'is_quote_status', 'is_reply_to_status', 'is_reply_to_user',
#        'numMentions', 'image_urls', 'retweet_count', 'favorite_count',
#        'user_id', 'user_name', 'user_screen', 'user_verified', 'user_lang',
#        'user_description_text', 'user_followers_count', 'user_friends_count',
#        'user_listed_count', 'user_favourites_count', 'user_statuses_count',
#        'user_location', 'user_created_year', 'user_created_month',
#        'user_geo_enabled', 'user_img_url', 'user_banner_url', 'category'],
#       dtype='object')

# %% [markdown]
# ## NOW, NEW FEATURES:
# **`text`**`: str:str:still tweet text, but now not truncated if >140chars`<br>
# **`image_urls`**`: list:[url1,url2,...]:list of urls for images that were found within body of the tweet!`<br>
# **`category`**`: str:str:manually labeled category type for this user`<br>
# label meanings for category = {'a':'artist','b':'businessLeader','c':'company','p':'politician','t':'athlete'}

# %%
#check what % of top100's tweets were from what category
res['category'].value_counts()/len(res)
# Out:
# artist            0.636909
# company           0.191065
# athlete           0.077660
# politician        0.067027
# businessLeader    0.027339
# Name: category, dtype: float64

# %%
#write out the *csv [and *pkl] file! good to go!
res.to_csv('./top100users_and_timelines_EXTENDED_PLUS.csv',index=False)
res.to_pickle('./top100users_and_timelines_EXTENDED_PLUS.pkl')

# %% [markdown]
# # BELOW: testing out some merge features. nothing important

# %%
df_a = pd.read_csv('./top100users_and_timelines.csv',index_col=None, lineterminator='\n')
df_b = pd.read_csv('./top100users_and_timelines_EXTENDED.csv',index_col=None, lineterminator='\n')
# Out:
# /Users/olderhorselover/USC/fall2018/csci599/teamrepo/social-swear/swear-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Out:
# Index(['tweet_id', 'tweet_truncated', 'date', 'tweet_source', 'tweet_coord',
#        'tweet_place', 'text', 'text_noMentions', 'is_quote_status',
#        'is_reply_to_status', 'is_reply_to_user', 'numMentions', 'image_urls',
#        'retweet_count', 'favorite_count', 'user_id', 'user_verified',
#        'user_description_text', 'user_followers_count', 'user_friends_count',
#        'user_listed_count', 'user_favourites_count', 'user_statuses_count',
#        'user_location', 'user_created_year', 'user_created_month',
#        'user_geo_enabled', 'user_img_url', 'user_banner_url', 'category'],
#       dtype='object')

# %%
cols = list(set(df_b.columns) - set(df_a.columns))
cols.append('tweet_id')
cols
# Out:
# ['tweet_coord',
#  'user_banner_url',
#  'user_created_year',
#  'tweet_source',
#  'tweet_truncated',
#  'user_geo_enabled',
#  'user_location',
#  'tweet_place',
#  'category',
#  'image_urls',
#  'user_img_url',
#  'user_created_month',
#  'tweet_id']

# %%
cols = list(set(df_b.columns) - set(df_a.columns))
cols.append('tweet_id')
tweets = pd.merge(df_a, df_b[cols], on=['tweet_id'], how='left')

# %%
df_a.shape
# Out:
# (203256, 18)

# %%
df_b.shape
# Out:
# (203993, 30)

# %%
tweets.shape
# Out:
# (203256, 30)

# %%
print(tweets.groupby('user_id').category.value_counts())
# Out:
# user_id     category
# 428333      company           2557
# 742143      company           2034
# 759251      company           1095
# 783214      company           2815
# 807095      company           1441
# 813286      politician        2842
# 2557521     company           2190
# 5988062     company           2021
# 10228272    company           2596
# 11348282    company           2353
# 14230524    artist            2376
# 14920785    artist            2906
# 15485441    artist            2809
# 15846407    artist            3020
# 16409683    artist            2875
# 17471979    company           2977
# 17919972    artist              71
# 18681139    artist            2517
# 18839785    politician        2859
# 18863815    artist            2575
# 19248106    artist            2259
# 19397785    artist            2819
# 19426551    athlete           1441
# 19895282    artist            3050
# 20322929    artist            1876
# 20536157    company           2790
# 21111883    artist            2303
# 22940219    artist             683
# 23083404    athlete           2732
# 23151437    artist            2203
#                               ...
# 44409004    artist            2239
# 50393960    businessLeader    2683
# 60865434    athlete           3165
# 73992972    artist            2298
# 79293791    artist            2931
# 84279963    artist            2997
# 85452649    artist             193
# 85603854    artist            2011
# 88856792    artist             620
# 90836187    athlete           1829
# 96951800    athlete           2928
# 100220864   artist            2756
# 101695592   artist            1497
# 113419517   artist            2793
# 115485051   artist            3185
# 116362700   artist            1831
# 119509520   artist            2613
# 132385468   artist            3204
# 158314798   artist            2757
# 166739404   artist            1151
# 169686021   artist             644
# 176566242   artist            2780
# 181561712   artist            3084
# 184910040   artist             279
# 209708391   artist            1911
# 236699098   artist            1748
# 268414482   artist            2552
# 379408088   artist            2273
# 627673190   athlete           2641
# 1339835893  politician        2507
# Name: category, Length: 74, dtype: int64

# %%
tweets
# Out:
#                    tweet_id                            date   user_id  \
# 0       1058069851678199809  Thu Nov 01 18:54:45 +0000 2018  27260086
# 1       1057450782528684032  Wed Oct 31 01:54:47 +0000 2018  27260086
# 2       1057450701737979904  Wed Oct 31 01:54:28 +0000 2018  27260086
# 3       1056709958991892480  Mon Oct 29 00:51:01 +0000 2018  27260086
# 4       1055173683222904832  Wed Oct 24 19:06:24 +0000 2018  27260086
# 5       1055173432101519361  Wed Oct 24 19:05:25 +0000 2018  27260086
# 6       1055173147215970304  Wed Oct 24 19:04:17 +0000 2018  27260086
# 203240  Did a secret show in NYC for @SIRIUSXM . Hear ...
# 203241  Coming to North American this summer, go here ...
# 203242  Spent 2 weeks with @PatrickDoyleRS, we had our...
# 203243            Going on Howard Stern today, tune in yo
# 203244  My first Rolling Stone cover, everywhere frida...
# 203245                    Everything's coming up Milhouse
# 203246  Happy Independence Day to Ghana! I had a wonde...
# 203247             Thank you iheart, New York bound now X
# 203248                Thank you ! https://t.co/ZNY77euZXW
# 203249                chicken for breakfast. wingz an dat
# 203250  Just got to LA, iheart radio awards tomorrow, ...
# 203251  Thank you to Blunty for presenting my Goldene ...
# 203252  @valstones this is beautiful and exactly the r...
# 203253  Quitting music, found a new job. New album out...
# 203254  Lovely seeing all the reactions to the record....
# 203255  @JamesBlunt lets celebrate our albums coming o...
#
#                                           text_noMentions  is_quote_status  \
# 0                               Congrats on the new song!            False
# 1                                        NO_USER_MENTIONS            False
# 2       I have listened to this album 10 times in a ro...            False
# 3                                        NO_USER_MENTIONS            False
# 4                                        NO_USER_MENTIONS            False
# 5                                        NO_USER_MENTIONS             True
# 6                                        NO_USER_MENTIONS            False
# 7                                        NO_USER_MENTIONS             True
# 8                                        NO_USER_MENTIONS             True
# 9                                        NO_USER_MENTIONS            False
# 10      Make sure you guys go see #CrazyRichAsians thi...            False
# 11                                       NO_USER_MENTIONS            False
# 12                                       NO_USER_MENTIONS            False
# 13                                       NO_USER_MENTIONS            False
# 14                                       NO_USER_MENTIONS            False
# 15                                       NO_USER_MENTIONS            False
# 16                                           Thank you  💍            False
# 17                                       NO_USER_MENTIONS             True
# 18                                       NO_USER_MENTIONS            False
# 19                                       NO_USER_MENTIONS             True
# 20                                       NO_USER_MENTIONS            False
# 21                                       NO_USER_MENTIONS            False
# 22                  Proud of my brother  on his new album            False
# 23                                       NO_USER_MENTIONS            False
# 24      #Hard2FaceReality   \nhttps://t.co/IXMbZOFNiR ...            False
# 25                                       NO_USER_MENTIONS             True
# 26                                       NO_USER_MENTIONS            False
# 27                                       NO_USER_MENTIONS            False
# 28                                       NO_USER_MENTIONS             True
# 29                                       NO_USER_MENTIONS            False
# ...                                                   ...              ...
# 203226                                   NO_USER_MENTIONS            False
# 203227              Can't wait  x https://t.co/BGoKXVqUZp            False
# 203228                                   NO_USER_MENTIONS            False
# 203229  no worries, i tried to trend it with  a week a...            False
# 203230                                   NO_USER_MENTIONS             True
# 203231  Playing an extra show at  on 22nd June for the...            False
# 203232                                   NO_USER_MENTIONS             True
# 203233                                   NO_USER_MENTIONS            False
# 203234  been working with  for , check it out - https:...            False
# 203235                                   NO_USER_MENTIONS            False
# 203236                                   NO_USER_MENTIONS            False
# 203237                                   NO_USER_MENTIONS            False
# 203238                                                 ❤️            False
# 203239                                   absolutely bonks            False
# 203240  Did a secret show in NYC for  . Hear it on  an...            False
# 203241                                   NO_USER_MENTIONS            False
# 203242  Spent 2 weeks with , we had ourselves a good t...             True
# 203243                                   NO_USER_MENTIONS            False
# 203244                                   NO_USER_MENTIONS            False
# 203245                                   NO_USER_MENTIONS            False
# 203246  Happy Independence Day to Ghana! I had a wonde...            False
# 203247                                   NO_USER_MENTIONS            False
# 203248                                   NO_USER_MENTIONS             True
# 203249                                   NO_USER_MENTIONS            False
# 203250                                   NO_USER_MENTIONS            False
# 203251                                   NO_USER_MENTIONS            False
# 203252  this is beautiful and exactly the reason why I...            False
# 203253                                   NO_USER_MENTIONS            False
# 203254                                   NO_USER_MENTIONS            False
# 203255  lets celebrate our albums coming out this mont...            False
#
#         is_reply_to_status  is_reply_to_user  numMentions  user_verified  \
# 0                     True              True            1           True
# 1                    False             False            0           True
# 2                     True              True            1           True
# 3                    False             False            0           True
# 4                    False             False            0           True
# 5                    False             False            0           True
# 6                    False             False            0           True
# 7                    False             False            0           True
# 8                    False             False            0           True
# 9                    False             False            0           True
# 10                   False             False            1           True
# 11                   False             False            0           True
# 12                   False             False            0           True
# 13                   False             False            0           True
# 14                   False             False            0           True
# 15                   False             False            0           True
# 16                   False             False            1           True
# 17                   False             False            0           True
# 18                   False             False            0           True
# 19                   False             False            0           True
# 20                   False             False            0           True
# 21                   False             False            0           True
# 22                   False             False            1           True
# 23                   False             False            0           True
# 24                   False             False            2           True
# 25                   False             False            0           True
# 26                   False             False            0           True
# 27                   False             False            0           True
# 28                   False             False            0           True
# 29                   False             False            0           True
# ...                    ...               ...          ...            ...
# 203226               False             False            0           True
# 203227               False             False            1           True
# 203228               False             False            0           True
# 203229                True              True            2           True
# 203230               False             False            0           True
# 203231               False             False            1           True
# 203232               False             False            0           True
# 203233               False             False            0           True
# 203234               False             False            2           True
# 203235               False             False            0           True
# 203236               False             False            0           True
# 203237               False             False            0           True
# 203238                True              True            1           True
# 203239                True              True            1           True
# 203240               False             False            2           True
# 203241               False             False            0           True
# 203242               False             False            1           True
# 203243               False             False            0           True
# 203244               False             False            0           True
# 203245               False             False            0           True
# 203246               False             False            1           True
# 203247               False             False            0           True
# 203248               False             False            0           True
# 203249               False             False            0           True
# 203250               False             False            0           True
# 203251               False             False            0           True
# 203252                True              True            1           True
# 203253               False             False            0           True
# 203254               False             False            0           True
# 203255                True              True            1           True
#
#               ...         user_created_year  tweet_source  tweet_truncated  \
# 0             ...                    2009.0        iphone            False
# 1             ...                    2009.0        iphone            False
# 2             ...                    2009.0        iphone            False
# 3             ...                    2009.0        iphone            False
# 4             ...                    2009.0        iphone            False
# 5             ...                    2009.0        iphone            False
# 6             ...                    2009.0        iphone            False
# 7             ...                    2009.0        iphone            False
# 8             ...                    2009.0        iphone            False
# 9             ...                    2009.0        iphone            False
# 10            ...                    2009.0        iphone            False
# 11            ...                    2009.0        iphone            False
# 12            ...                    2009.0           web            False
# 13            ...                    2009.0           web            False
# 14            ...                    2009.0        iphone            False
# 15            ...                    2009.0        iphone            False
# 16            ...                    2009.0        iphone            False
# 17            ...                    2009.0           web            False
# 18            ...                    2009.0        iphone            False
# 19            ...                    2009.0        iphone            False
# 20            ...                    2009.0        iphone            False
# 21            ...                    2009.0           web            False
# 22            ...                    2009.0        iphone            False
# 23            ...                    2009.0           web            False
# 24            ...                    2009.0           web            False
# 25            ...                    2009.0        iphone            False
# 26            ...                    2009.0        iphone            False
# 27            ...                    2009.0        iphone            False
# 28            ...                    2009.0        iphone            False
# 29            ...                    2009.0        iphone            False
# ...           ...                       ...           ...              ...
# 203226        ...                    2009.0          ipad            False
# 203227        ...                    2009.0     instagram            False
# 203228        ...                    2009.0           web            False
# 203229        ...                    2009.0           web            False
# 203230        ...                    2009.0          ipad            False
# 203231        ...                    2009.0          ipad            False
# 203232        ...                    2009.0           web            False
# 203233        ...                    2009.0     instagram            False
# 203234        ...                    2009.0           web            False
# 203235        ...                    2009.0           web            False
# 203236        ...                    2009.0     instagram            False
# 203237        ...                    2009.0          ipad            False
# 203238        ...                    2009.0          ipad            False
# 203239        ...                    2009.0          ipad            False
# 203240        ...                    2009.0        iphone            False
# 203241        ...                    2009.0           web            False
# 203242        ...                    2009.0          ipad            False
# 203243        ...                    2009.0          ipad            False
# 203244        ...                    2009.0     instagram            False
# 203245        ...                    2009.0          ipad            False
# 203246        ...                    2009.0          ipad            False
# 203247        ...                    2009.0          ipad            False
# 203248        ...                    2009.0          ipad            False
# 203249        ...                    2009.0           web            False
# 203250        ...                    2009.0          ipad            False
# 203251        ...                    2009.0     instagram            False
# 203252        ...                    2009.0          ipad            False
# 203253        ...                    2009.0          ipad            False
# 203254        ...                    2009.0          ipad            False
# 203255        ...                    2009.0          ipad            False
#
#         user_geo_enabled  user_location  tweet_place  category  \
# 0                  False            NaN          NaN    artist
# 1                  False            NaN          NaN    artist
# 2                  False            NaN          NaN    artist
# 3                  False            NaN          NaN    artist
# 4                  False            NaN          NaN    artist
# 5                  False            NaN          NaN    artist
# 6                  False            NaN          NaN    artist
# 7                  False            NaN          NaN    artist
# 8                  False            NaN          NaN    artist
# 9                  False            NaN          NaN    artist
# 10                 False            NaN          NaN    artist
# 11                 False            NaN          NaN    artist
# 12                 False            NaN          NaN    artist
# 13                 False            NaN          NaN    artist
# 14                 False            NaN          NaN    artist
# 15                 False            NaN          NaN    artist
# 16                 False            NaN          NaN    artist
# 17                 False            NaN          NaN    artist
# 18                 False            NaN          NaN    artist
# 19                 False            NaN          NaN    artist
# 20                 False            NaN          NaN    artist
# 21                 False            NaN          NaN    artist
# 22                 False            NaN          NaN    artist
# 23                 False            NaN          NaN    artist
# 24                 False            NaN          NaN    artist
# 25                 False            NaN          NaN    artist
# 26                 False            NaN          NaN    artist
# 27                 False            NaN          NaN    artist
# 28                 False            NaN          NaN    artist
# 29                 False            NaN          NaN    artist
# ...                  ...            ...          ...       ...
# 203226              True         London          NaN    artist
# 203227              True         London          NaN    artist
# 203228              True         London          NaN    artist
# 203229              True         London          NaN    artist
# 203230              True         London          NaN    artist
# 203231              True         London          NaN    artist
# 203232              True         London          NaN    artist
# 203233              True         London          NaN    artist
# 203234              True         London          NaN    artist
# 203235              True         London          NaN    artist
# 203236              True         London          NaN    artist
# 203237              True         London          NaN    artist
# 203238              True         London          NaN    artist
# 203239              True         London          NaN    artist
# 203240              True         London          NaN    artist
# 203241              True         London          NaN    artist
# 203242              True         London          NaN    artist
# 203243              True         London          NaN    artist
# 203244              True         London          NaN    artist
# 203245              True         London          NaN    artist
# 203246              True         London          NaN    artist
# 203247              True         London          NaN    artist
# 203248              True         London          NaN    artist
# 203249              True         London          NaN    artist
# 203250              True         London          NaN    artist
# 203251              True         London          NaN    artist
# 203252              True         London          NaN    artist
# 203253              True         London          NaN    artist
# 203254              True         London          NaN    artist
# 203255              True         London          NaN    artist
#
#                                                image_urls  \
# 0                                                     NaN
# 1       ['http://pbs.twimg.com/media/DqzR4XyU8AEboPA.j...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9       ['http://pbs.twimg.com/media/Dk1VChSU0AATpXg.j...
# 10                                                    NaN
# 11      ['http://pbs.twimg.com/ext_tw_video_thumb/1027...
# 12                                                    NaN
# 13      ['http://pbs.twimg.com/media/DjZBQTwV4AA9zFp.j...
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18      ['http://pbs.twimg.com/media/De8gWblUEAA-WQn.j...
# 19                                                    NaN
# 20                                                    NaN
# 21      ['http://pbs.twimg.com/media/DdMCr56W0AI9Sdd.j...
# 22                                                    NaN
# 23                                                    NaN
# 24      ['http://pbs.twimg.com/media/DaFDSKaVQAAKE7x.j...
# 25                                                    NaN
# 26                                                    NaN
# 27      ['http://pbs.twimg.com/media/DYvqCtUUQAAv4QZ.j...
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 203226                                                NaN
# 203227                                                NaN
# 203228  ['http://pbs.twimg.com/ext_tw_video_thumb/8423...
# 203229                                                NaN
# 203230                                                NaN
# 203231                                                NaN
# 203232                                                NaN
# 203233                                                NaN
# 203234                                                NaN
# 203235                                                NaN
# 203236                                                NaN
# 203237                                                NaN
# 203238                                                NaN
# 203239                                                NaN
# 203240                                                NaN
# 203241  ['http://pbs.twimg.com/ext_tw_video_thumb/8394...
# 203242                                                NaN
# 203243                                                NaN
# 203244                                                NaN
# 203245                                                NaN
# 203246                                                NaN
# 203247                                                NaN
# 203248                                                NaN
# 203249                                                NaN
# 203250                                                NaN
# 203251                                                NaN
# 203252                                                NaN
# 203253  ['http://pbs.twimg.com/ext_tw_video_thumb/8376...
# 203254                                                NaN
# 203255                                                NaN
#
#                                              user_img_url user_created_month
# 0       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 1       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 2       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 3       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 4       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 5       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 6       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 7       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 8       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 9       http://pbs.twimg.com/profile_images/8982953118...                3.0
# 10      http://pbs.twimg.com/profile_images/8982953118...                3.0
# 11      http://pbs.twimg.com/profile_images/8982953118...                3.0
